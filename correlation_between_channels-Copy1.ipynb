# %%
import gps_particle_data
import wget
import os
import numpy as np 
import time
import json
import sys
import math
from datetime import datetime, timedelta, date
from itertools import compress
from random import randint
import urllib2
import aacgmv2
import scipy
import matplotlib
from matplotlib import gridspec
import numpy as np
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# %%
#Collecting data and avoiding nuclear tests
for j in range(12):
    #These lines just reduce amount of data?
    if j == 0 or j == 1 or j==2:
        continue
    start_date = datetime(2013,j+1,10,0,0,0);
    end_date = datetime(2013,j+1,23,0,0,0);
    ms = gps_particle_data.meta_search();
    ms.load_data(start_date,end_date);
    
    output_data = ms.get_all_data_by_satellite()
    signal = 'rate_electron_measured'
    for i in range(11):
        a0 = np.asarray(output_data[54][signal])[:,2]
        ar2 = np.asarray(output_data[54][signal])[:,i]
        #Normalised cross-correlation between channel 2 and all other channels for a given time period.
        cor = np.correlate(a0, ar2)/(math.sqrt(np.sum(a0**2)*np.sum(ar2**2)))
        fname = 'ch2_'+str(i)+'.ascii'
        with open(fname, 'a') as f:
            np.savetxt(f, cor)
        if i == 2 :
            print 'channel:', i, 'X-cor  --->   ', cor[0]
    
    cont = np.loadtxt('ch2_0.ascii')
    print cont
# Out:
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_130414_v1.03.ascii
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_130421_v1.03.ascii
# channel: 2 X-cor  --->    1.0
# [ 0.90863931  0.63455695  0.93376742  0.97550749  0.90345793  0.81578119
#   0.85860038  0.90060803  0.82196739  0.90863931  0.63455695  0.93376742
#   0.97550749  0.90345793  0.81578119  0.85860038  0.90060803  0.82196739
#   0.90863931  0.63455695  0.93376742  0.97550749  0.90345793  0.81578119
#   0.85860038  0.90060803  0.82196739  0.35122579  0.74856224  0.839795
#   0.92837109  0.71006134  0.88929815  0.3939341   0.78109463  0.86978279
#   0.48154732  0.78313676  0.88341039  0.93947659  0.79617869  0.90863931]
#
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_130512_v1.03.ascii
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_130519_v1.03.ascii
# channel: 2 X-cor  --->    1.0
# [ 0.90863931  0.63455695  0.93376742  0.97550749  0.90345793  0.81578119
#   0.85860038  0.90060803  0.82196739  0.90863931  0.63455695  0.93376742
#   0.97550749  0.90345793  0.81578119  0.85860038  0.90060803  0.82196739
#   0.90863931  0.63455695  0.93376742  0.97550749  0.90345793  0.81578119
#   0.85860038  0.90060803  0.82196739  0.35122579  0.74856224  0.839795
#   0.92837109  0.71006134  0.88929815  0.3939341   0.78109463  0.86978279
#   0.48154732  0.78313676  0.88341039  0.93947659  0.79617869  0.90863931
#   0.63455695]
#
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_130616_v1.03.ascii
